# %%
# Step 1: Install necessary packages
# !pip install ydata-profiling
# !pip install -U pandas

# Step 2: Import libraries
import pandas as pd
from ydata_profiling import ProfileReport

# Step 3: Load the dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# Step 4: Generate the profiling report
profile = ProfileReport(df, title="Titanic Dataset Profiling Report", explorative=True)

# Step 5: Display the report in the Colab notebook
profile.to_notebook_iframe()
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.8.3-py2.py3-none-any.whl.metadata (20 kB)
# Collecting scipy<1.14,>=1.4.1 (from ydata-profiling)
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 429.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from ydata-profiling) (2.2.2)
# Collecting matplotlib<3.9,>=3.2 (from ydata-profiling)
#   Using cached matplotlib-3.8.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: pydantic>=2 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from ydata-profiling) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from ydata-profiling) (3.1.4)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling)
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Collecting numpy<2,>=1.16.0 (from ydata-profiling)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: htmlmin==0.1.12 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from ydata-profiling) (4.66.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from ydata-profiling) (1.12)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Downloading statsmodels-0.14.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Downloading typeguard-4.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: imagehash==4.3.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from ydata-profiling) (4.3.1)
# Collecting wordcloud>=1.9.1 (from ydata-profiling)
#   Downloading wordcloud-1.9.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Collecting numba<1,>=0.56.0 (from ydata-profiling)
#   Downloading numba-0.60.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: PyWavelets in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from imagehash==4.3.1->ydata-profiling) (1.6.0)
# Requirement already satisfied: pillow in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from imagehash==4.3.1->ydata-profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (2.9.0.post0)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba<1,>=0.56.0->ydata-profiling)
#   Downloading llvmlite-0.43.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.7.4)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: attrs>=19.3.0 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.3)
# Requirement already satisfied: six in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Downloading ydata_profiling-4.8.3-py2.py3-none-any.whl (359 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.5/359.5 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Using cached matplotlib-3.8.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Downloading numba-0.60.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 7.0 MB/s eta 0:00:0000:0100:01
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 7.3 MB/s eta 0:00:0000:0100:01
# Downloading statsmodels-0.14.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 6.2 MB/s eta 0:00:0000:0100:01
# Downloading typeguard-4.3.0-py3-none-any.whl (35 kB)
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.4 MB/s eta 0:00:00
# Downloading wordcloud-1.9.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (541 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.6/541.6 kB 7.4 MB/s eta 0:00:0000:0100:01
# Downloading llvmlite-0.43.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 5.8 MB/s eta 0:00:0000:0100:01
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 7.5 MB/s eta 0:00:00
# Installing collected packages: typeguard, numpy, llvmlite, dacite, scipy, patsy, numba, visions, statsmodels, matplotlib, wordcloud, ydata-profiling
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.0
#     Uninstalling scipy-1.14.0:
#       Successfully uninstalled scipy-1.14.0
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.9.1
#     Uninstalling matplotlib-3.9.1:
#       Successfully uninstalled matplotlib-3.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# Successfully installed dacite-1.8.1 llvmlite-0.43.0 matplotlib-3.8.4 numba-0.60.0 numpy-1.26.4 patsy-0.5.6 scipy-1.13.1 statsmodels-0.14.2 typeguard-4.3.0 visions-0.7.6 wordcloud-1.9.3 ydata-profiling-4.8.3
# Requirement already satisfied: pandas in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       5 # Step 2: Import libraries
#       6 import pandas as pd
# ----> 7 from ydata_profiling import ProfileReport
#       9 # Step 3: Load the dataset
#      10 url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/ydata_profiling/__init__.py:14
#      10 warnings.simplefilter("ignore", category=NumbaDeprecationWarning)
#      12 import importlib.util  # isort:skip # noqa
# ---> 14 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      15 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      16 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/ydata_profiling/compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/ydata_profiling/profile_report.py:31
#      29 from ydata_profiling.model import BaseDescription
#      30 from ydata_profiling.model.alerts import AlertType
# ---> 31 from ydata_profiling.model.describe import describe as describe_df
#      32 from ydata_profiling.model.sample import Sample
#      33 from ydata_profiling.model.summarizer import (
#      34     BaseSummarizer,
#      35     PandasProfilingSummarizer,
#      36     format_summary,
#      37     redact_summary,
#      38 )
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/ydata_profiling/model/describe.py:20
#      18 from ydata_profiling.model.duplicates import get_duplicates
#      19 from ydata_profiling.model.missing import get_missing_active, get_missing_diagram
# ---> 20 from ydata_profiling.model.pairwise import get_scatter_plot, get_scatter_tasks
#      21 from ydata_profiling.model.sample import get_custom_sample, get_sample
#      22 from ydata_profiling.model.summarizer import BaseSummarizer
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/ydata_profiling/model/pairwise.py:6
#       3 import pandas as pd
#       5 from ydata_profiling.config import Settings
# ----> 6 from ydata_profiling.visualisation.plot import scatter_pairwise
#       9 def get_scatter_tasks(
#      10     config: Settings, continuous_variables: list
#      11 ) -> List[Tuple[Any, Any]]:
#      12     if not config.interactions.continuous:
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/ydata_profiling/visualisation/plot.py:15
#      13 from matplotlib.patches import Patch
#      14 from matplotlib.ticker import FuncFormatter, MaxNLocator
# ---> 15 from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#      16 from typeguard import typechecked
#      17 from wordcloud import WordCloud
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/statsmodels/__init__.py:1
# ----> 1 from statsmodels.compat.patsy import monkey_patch_cat_dtype
#       3 from statsmodels._version import __version__, __version_tuple__
#       5 __version_info__ = __version_tuple__
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/statsmodels/compat/__init__.py:1
# ----> 1 from statsmodels.tools._testing import PytestTester
#       3 from .python import (
#       4     asunicode,
#       5     asbytes,
#    (...)
#      10     lfilter,
#      11 )
#      13 __all__ = [
#      14     "asunicode",
#      15     "asbytes",
#    (...)
#      21     "test",
#      22 ]
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/statsmodels/tools/__init__.py:1
# ----> 1 from .tools import add_constant, categorical
#       2 from statsmodels.tools._testing import PytestTester
#       4 __all__ = ['test', 'add_constant', 'categorical']
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/statsmodels/tools/tools.py:6
#       4 import numpy as np
#       5 import pandas as pd
# ----> 6 import scipy.linalg
#       8 from statsmodels.tools.data import _is_using_pandas
#       9 from statsmodels.tools.validation import array_like
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/scipy/linalg/__init__.py:205
#     203 from ._misc import *
#     204 from ._cythonized_array_utils import *
# --> 205 from ._basic import *
#     206 from ._decomp import *
#     207 from ._decomp_lu import *
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/scipy/linalg/_basic.py:13
#      11 from .lapack import get_lapack_funcs, _compute_lwork
#      12 from ._misc import LinAlgError, _datacopied, LinAlgWarning
# ---> 13 from ._decomp import _asarray_validated
#      14 from . import _decomp, _decomp_svd
#      15 from ._solve_toeplitz import levinson
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/scipy/linalg/_decomp.py:26
#      22 from numpy import (array, isfinite, inexact, nonzero, iscomplexobj,
#      23                    flatnonzero, conj, asarray, argsort, empty,
#      24                    iscomplex, zeros, einsum, eye, inf)
#      25 # Local imports
# ---> 26 from scipy._lib._util import _asarray_validated
#      27 from ._misc import LinAlgError, _datacopied, norm
#      28 from .lapack import get_lapack_funcs, _compute_lwork
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/scipy/_lib/_util.py:18
#      10 from typing import (
#      11     Optional,
#      12     Union,
#      13     TYPE_CHECKING,
#      14     TypeVar,
#      15 )
#      17 import numpy as np
# ---> 18 from scipy._lib._array_api import array_namespace
#      21 AxisError: type[Exception]
#      22 ComplexWarning: type[Warning]
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/scipy/_lib/_array_api.py:17
#      14 import numpy as np
#      16 from scipy._lib import array_api_compat
# ---> 17 from scipy._lib.array_api_compat import (
#      18     is_array_api_obj,
#      19     size,
#      20     numpy as np_compat,
#      21 )
#      23 __all__ = ['array_namespace', '_asarray', 'size']
#      26 # To enable array API and strict array-like input validation
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/scipy/_lib/array_api_compat/numpy/__init__.py:1
# ----> 1 from numpy import *
#       3 # from numpy import * doesn't overwrite these builtin names
#       4 from numpy import abs, max, min, round
#
# File ~/miniconda3/envs/pandas/lib/python3.12/site-packages/numpy/__init__.py:367, in __getattr__(attr)
#     365         raise AssertionError()
#     366 except AssertionError:
# --> 367     msg = ("The current Numpy installation ({!r}) fails to "
#     368            "pass simple sanity checks. This can be caused for example "
#     369            "by incorrect BLAS library being linked in, or by mixing "
#     370            "package managers (pip, conda, apt, ...). Search closed "
#     371            "numpy issues for similar problems.")
#     372     raise RuntimeError(msg.format(__file__)) from None
#
# ModuleNotFoundError: No module named 'numpy.char'

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /home/pk/miniconda3/envs/pandas/lib/python3.12/site-packages (1.26.4)
